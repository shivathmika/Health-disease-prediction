# %%
# !unzip "/content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main.zip" -d "/content/drive/MyDrive/Health Disease Risk assessment/"
# Out:
# Archive:  /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main.zip
# 131794eaa422b5a89eb81595bd2a487d42d43b93
#    creating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/
#   inflating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/.gitignore
#   inflating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/README.md
#   inflating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/app.py
#   inflating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/dummy_model.py
#    creating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/instance/
#   inflating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/instance/users.db
#    creating: /content/drive/MyDrive/Health Disease Risk assessment/doctor_dashboard-main/models/
# ...
