# %%
import os
os.chdir('/content/drive/MyDrive/Health Disease Risk assessment/Diabeties/src')

# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached scikit_learn-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached matplotlib-3.8.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# ...
#   Using cached lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached pickle5-0.0.11.tar.gz (132 kB)
#   Preparing metadata (setup.py) ... done
# ...
# Using cached scikit_learn-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# Using cached matplotlib-3.8.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
# Using cached lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
# ...

# %%
import pickle

# %%
# !python create_folds.py
# Out:
# file saved in destination

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 136:	learn: 0.4833780	total: 192ms	remaining: 88.2ms
# 137:	learn: 0.4830649	total: 193ms	remaining: 86.6ms
# 138:	learn: 0.4825909	total: 193ms	remaining: 84.9ms
# 77:	learn: 0.5246346	total: 103ms	remaining: 160ms
# 78:	learn: 0.5238095	total: 103ms	remaining: 158ms
# 139:	learn: 0.4820821	total: 195ms	remaining: 83.8ms
# 140:	learn: 0.4816479	total: 196ms	remaining: 82.1ms
# 141:	learn: 0.4811632	total: 197ms	remaining: 80.5ms
# 79:	learn: 0.5224299	total: 104ms	remaining: 156ms
# 80:	learn: 0.5217479	total: 105ms	remaining: 154ms
# 81:	learn: 0.5206005	total: 105ms	remaining: 152ms
# 142:	learn: 0.4805265	total: 198ms	remaining: 78.8ms
# 143:	learn: 0.4802004	total: 199ms	remaining: 77.2ms
# 82:	learn: 0.5198527	total: 106ms	remaining: 150ms
# 83:	learn: 0.5189291	total: 107ms	remaining: 148ms
# 144:	learn: 0.4797211	total: 199ms	remaining: 75.6ms
# 84:	learn: 0.5181238	total: 108ms	remaining: 146ms
# ...

# %%
import catboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-4c4156b93204> in <cell line: 0>()
# ----> 1 import catboost
#
# ModuleNotFoundError: No module named 'catboost'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.9 MB/s eta 0:00:00
# ...
